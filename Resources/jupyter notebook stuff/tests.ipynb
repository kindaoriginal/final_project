# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.graph_objects as go

# %%
columns = ["title", "rating","vote_count", "release_date", "runtime", "genre", "budget", "revenue"]

# %%
df = pd.read_csv(r"C:/Users/Ashton/Desktop/Movie Data/final_project/Resources/movies_metadata.csv", usecols=columns)

# %%
df.dtypes
# Out:
# budget            int64
# release_date     object
# revenue           int64
# runtime         float64
# title            object
# rating          float64
# vote_count        int64
# genre            object
# dtype: object

# %%
df
# Out:
#         budget release_date    revenue  runtime                       title  \
# 0      3500000    1/24/1970   81600000    116.0                     M*A*S*H
# 1     12000000    1/25/1970   89800000    172.0                      Patton
# 2     25485000    1/26/1970   29548291    144.0           Tora! Tora! Tora!
# 3     11000000    1/27/1970    2200000    124.0          The Molly Maguires
# 4      7000000     2/9/1970    1000000    113.0             Zabriskie Point
# ...        ...          ...        ...      ...                         ...
# 6260  11000000     8/3/2017  184770205    111.0                  Wind River
# 6261  21000000     8/4/2017   24527158     95.0                      Kidnap
# 6262   4696772   10/27/2017          0    130.0        Call Me by Your Name
# 6263  18000000     3/1/2018          0      0.0   Iron Sky: The Coming Race
# 6264  12000000   12/31/2018          0      0.0  The Other Side of the Wind
#
#       rating  vote_count    genre
# ...

# %%
df_samp1 = df.sample(frac = .01)

# %%
df_samp1
# Out:
#          budget release_date    revenue  runtime                  title  \
# 3084  132000000    6/28/2005  591739379    116.0      War of the Worlds
# 3083   30000000    6/27/2005   25473093    105.0             Dark Water
# 2126   80000000   12/17/1999   90874570     74.0          Fantasia 2000
# 165     3500000    10/3/1975          0    110.0  The Master Gunfighter
# 697     8500000     6/6/1986   16209459    106.0               Raw Deal
# ...         ...          ...        ...      ...                    ...
# 4893    5000000    5/11/2012    8493728     83.0            Piranha 3DD
# 2854   40000000     4/7/2004   26155781     98.0    The Whole Ten Yards
# 951     2000000    10/1/1989          0     96.0   Bride of Re-Animator
# 5887   60000000   12/11/2015          0    119.0       The Ridiculous 6
# 5935   35000000    2/24/2016   25182929     83.0                Grimsby
#
#       rating  vote_count      genre
# 3084     6.2        2397  Adventure
# ...

# %%
df_samp1.plot(x="title", y=["rating"], kind="bar", figsize=(15, 8))
plt.show()

# %%
dfgo = pd.read_csv("https://media.githubusercontent.com/media/kindaoriginal/final_project/main/Resources/movies_metadata.csv")

# %%
fig = go.Figure([go.Scatter(x=dfgo['release_date'], y=dfgo['revenue'])])
fig.show()
# Out:
# <div>                            <div id="5b7a5c62-6732-4725-9054-04b6efa1af8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5b7a5c62-6732-4725-9054-04b6efa1af8e")) {                    Plotly.newPlot(                        "5b7a5c62-6732-4725-9054-04b6efa1af8e",                        [{"x":["1/24/1970","1/25/1970","1/26/1970","1/27/1970","2/9/1970","2/10/1970","2/18/1970","3/5/1970","3/26/1970","4/10/1970","4/22/1970","5/1/1970","5/13/1970","5/20/1970","6/10/1970","6/22/1970","6/24/1970","6/24/1970","7/17/1970","7/22/1970","7/23/1970","9/9/1970","10/23/1970","10/26/1970","10/29/1970","11/8/1970","11/18/1970","12/8/1970","12/14/1970","12/16/1970","12/23/1970","1/1/1971","1/1/1971","1/15/1971","3/3/1971","3/11/1971","3/12/1971","4/23/1971","4/28
# ...
